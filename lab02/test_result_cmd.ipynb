# %%
using Plots
data_length = range(1, 12, length=12)
# # Plot the data
data = [
    [0.0455761 0.0189002],
    [0.0269816 0.0105798],
    [0.02455 0.0104463],
    [0.0205881 0.0085015],
    [0.0156128 0.0069595],
    [0.0159092 0.0067772],
    [0.0153069 0.0064976],
    [0.0138989 0.006219],
    [0.0151185 0.0060087],
    [0.0135956 0.0057872],
    [0.013266 0.0057214],
    [0.0108639 0.0044097]
]

folds_times = [data[i][1] for i in 1:length(data)]
floops_times = [data[i][2] for i in 1:length(data)]
plot(data_length, [folds_times floops_times], label=["folds" "floops"], title="Input = 1:10^7, Execution Time of SUM_MAX_MIN \nfunction using Folds.js and FLoop.jl")
xlabel!("number of thread used")
ylabel!("runnning time in (second)")

# %%
using Plots
data_length = range(1, 12, length=12)
# # Plot the data
data = [
   ## copy result from result100.txt -> result1000000.txt
]

folds_times = [data[i][1] for i in 1:length(data)]
floops_times = [data[i][2] for i in 1:length(data)]
plot(data_length, [folds_times floops_times], label=["folds" "floops"], title="Input 1:100, Execution Time of SUM_MAX_MIN \nfunction using Folds.js and FLoop.jl")
xlabel!("number of thread used")
ylabel!("runnning time in (second)")
