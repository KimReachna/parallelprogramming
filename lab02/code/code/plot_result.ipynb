# %%
using Plots
data_length = range(1, 12, length=12)
# # Plot the data
data = [
    [0.0001168, 0.1101136],
    [7.53e-5, 0.0933446],
    [7.72e-5, 0.0831346],
    [7.69e-5, 0.0557201],
    [6.35e-5, 0.0617134],
    [6.56e-5, 0.0509808],
    [6.01e-5, 0.0516884],
    [6.42e-5, 0.0429228],
    [7.4e-5, 0.0442069],
    [7.8e-5, 0.0419766],
    [7.36e-5, 0.0394425],
    [7.62e-5, 0.0398226]
]

folds_times = [data[i][1] for i in 1:length(data)]
floops_times = [data[i][2] for i in 1:length(data)]
plot(data_length, [folds_times floops_times], label=["folds" "floops"], title="Input = 1:1e6, Execution Time of SUM_MAX_MIN \nfunction using Folds.js and FLoop.jl")
xlabel!("number of thread used")
ylabel!("runnning time in (second)")

# %%
using Plots
data_length = range(1, 12, length=12)
# # Plot the data
data = [
    [0.0001167, 0.0009212],
    [7.02e-5, 0.0005449],
    [7.3e-5, 0.0005172],
    [5.86e-5, 0.0003448],
    [4.94e-5, 0.000343],
    [4.94e-5, 0.0003317],
    [5.02e-5, 0.0003096],
    [5.25e-5, 0.0002346],
    [5.11e-5, 0.0002295],
    [5.15e-5, 0.0002265],
    [4.28e-5, 0.0002351],
    [3.95e-5, 0.0002268]
]

folds_times = [data[i][1] for i in 1:length(data)]
floops_times = [data[i][2] for i in 1:length(data)]
plot(data_length, [folds_times floops_times], label=["folds" "floops"], title="Input = 1:10^7, Execution Time of Trapezoidal rule \nfunction using Folds.js and FLoop.jl")
xlabel!("number of thread used")
ylabel!("runnning time in (second)")
